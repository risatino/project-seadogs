# %%
import pandas as pd

# %%
#read in player_arrest.csv that was created in NFL_crime_records notebook
player_df = pd.read_csv("player_arrests.csv")
player_df.head()
# Out:
#           Name  Arrest Count Position           City Team Name
# 0  Kenny Britt             7       WR      Nashville    Titans
# 1  Aldon Smith             5       LB  San Francisco     49ers
# 2   Fred Davis             4       TE  Washington DC  Redskins
# 3   Leroy Hill             4       LB        Seattle  Seahawks
# 4   Adam Jones             4       CB     Cincinnati   Bengals

# %%
#add trade columns to df
player_df["Relinquished 1"] = ""
player_df["Relinquished 2"] = ""
player_df["Relinquished 3"] = ""
player_df["Relinquished 4"] = ""
player_df.head()
# Out:
#           Name  Arrest Count Position           City Team Name Relinquished 1  \
# 0  Kenny Britt             7       WR      Nashville    Titans
# 1  Aldon Smith             5       LB  San Francisco     49ers
# 2   Fred Davis             4       TE  Washington DC  Redskins
# 3   Leroy Hill             4       LB        Seattle  Seahawks
# 4   Adam Jones             4       CB     Cincinnati   Bengals
#
#   Relinquished 2 Relinquished 3 Relinquished 4
# 0
# 1
# 2
# 3
# 4

# %%
player_df["Name]""Kenny Britt"]["Relinquinshed 1"] = "2014-03-11"
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Kenny Britt'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-34b39ee4a357> in <module>()
# ...
