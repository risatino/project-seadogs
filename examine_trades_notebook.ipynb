# %%
#import dependencies
import pandas as pd

# %%
#pull in trade csv
trade_df = pd.read_csv("player_trade_data.csv")

#removed extra columns found in first look
trade_df.drop("Unnamed: 4", axis = 1, inplace = True)
trade_df.drop("Unnamed: 5", axis = 1, inplace = True)

#review
trade_df
# Out:
#                  Player Trade Date       Teams  \
# 0           Kenny Britt    4/25/09      Titans
# 1           Kenny Britt    3/11/14        Rams
# 2           Kenny Britt     3/9/17      Browns
# 3           Kenny Britt    12/8/17    Patriots
# 4           Aldon Smith    4/28/11       49ers
# 5           Aldon Smith     8/7/15     Raiders
# 6           Aldon Smith     3/5/18          na
# 7            Fred Davis    4/26/08    Redskins
# 8            Fred Davis    3/11/14    Patriots
# 9            Fred Davis    6/19/15          na
# 10           Leroy Hill    4/23/05    Seahawks
# 11           Leroy Hill    3/12/13          na
# 12           Adam Jones    4/23/05      Titans
# 13           Adam Jones    4/24/08     Cowboys
# 14           Adam Jones     1/7/09          na
# 15           Adam Jones    5/10/10     Bengals
# 16           Adam Jones     3/9/18          na
# 17         Johnny Jolly    4/29/06     Packers
# 18         Johnny Jolly    3/11/14          na
# ...

# %%
trade_groupby_player = trade_df.groupby(["Player"]).unique()
trade_groupby_player.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-0369473f114b> in <module>()
# ----> 1 trade_groupby_player = trade_df.groupby(["Player"]).unique()
#       2 trade_groupby_player.head()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py in __getattr__(self, attr)
#     549
#     550         raise AttributeError("%r object has no attribute %r" %
# --> 551                              (type(self).__name__, attr))
#     552
#     553     plot = property(GroupByPlot)
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'unique'
